# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

pd.set_option('mode.chained_assignment', None)

# %%
cameras_and_crashes= "Output Data/cameras_and_crashes.csv"
cameras_and_crashes_clean= "Output Data/cameras_and_crashes_clean.csv"
violations_cameras_clean= "Output Data/violations_cameras_clean.csv"

# %%
cameras_and_crashes_df= pd.read_csv(cameras_and_crashes)
cameras_and_crashes_clean_df= pd.read_csv(cameras_and_crashes_clean)
violations_cameras_clean_df= pd.read_csv(violations_cameras_clean)
cameras_and_crashes_clean_df.head()
# Out:
#         QUARTERLY BINS  TOTAL CRASHES  CAMERAS ADDED  TOTAL CAMERAS LIVE
# 0  2014-06-30 00:00:00              1             19                 124
# 1  2014-09-30 00:00:00              1             12                 136
# 2  2014-12-31 00:00:00              1              6                 142
# 3  2015-03-31 00:00:00              3              3                 145
# 4  2015-06-30 00:00:00              9              0                 145

# %%
x_values= cameras_and_crashes_clean_df['TOTAL CAMERAS LIVE']
y_values= cameras_and_crashes_clean_df['TOTAL CRASHES']

plt.title('TOTAL CAMERAS VS CRASHES')

plt.xlabel('TOTAL CAMERAS LIVE')
plt.ylabel('TOTAL CRASHES')
plt.scatter(x_values, y_values) 

plt.show()

# %%
#How does the number of speed cameras correlate with the amount of car crashes?

#linear

x_values= cameras_and_crashes_clean_df["TOTAL CAMERAS LIVE"]
y_values= cameras_and_crashes_clean_df["TOTAL CRASHES"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

plt.scatter(x_values, y_values) 
plt.title("TOTAL CAMERAS VS CRASHES")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(125,20000),fontsize=13,color="red")
plt.xlabel('TOTAL CAMERAS LIVE')
plt.ylabel('TOTAL CRASHES')

print(f"The r-squared is: {rvalue**2}")
print("How does the number of speed cameras correlate with the amount of car crashes?")
print("The regression shows a medium correlation.")
predicted_crashes= slope * 200 + intercept
print(f"For 2022, if the City of Chicago added enough cameras to get to 200 in total, we are predicting that the number of crashes would be {predicted_crashes}")
print("As the total number of cameras increases, the number of crashes increases.")

plt.show()
# Out:
# The r-squared is: 0.6148479658369282
# How does the number of speed cameras correlate with the amount of car crashes?
# The regression shows a medium correlation.
# For 2022, if the City of Chicago added enough cameras to get to 200 in total, we are predicting that the number of crashes would be 71362.98688998556
# As the total number of cameras increases, the number of crashes increases.

# %%
import datetime as dt
test="2014-06-30 00:00:00"
test_dt=dt.datetime.fromisoformat(test)
print(test_dt.date())
#dt.date.today().strftime("%d")
#cameras_and_crashes_clean_df.dtypes
# Out:
# 2014-06-30

# %%
cameras_and_crashes_clean_df["DATETIME"] = pd.to_datetime(cameras_and_crashes_clean_df["QUARTERLY BINS"])
type(cameras_and_crashes_clean_df["DATETIME"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
x_values= cameras_and_crashes_clean_df['DATETIME']
y_values= cameras_and_crashes_clean_df['TOTAL CRASHES']

plt.title('TOTAL CAMERAS VS CRASHES')

plt.xlabel('QUARTERS')
plt.ylabel('TOTAL CRASHES')
plt.plot(x_values, y_values) 
plt.xticks(rotation=90)

plt.show()

# %%
x_violation= violations_cameras_clean_df["TOTAL CAMERAS LIVE"]
y_violation= violations_cameras_clean_df["TOTAL VIOLATIONS"]

plt.title('TOTAL CAMERAS VS VIOLATIONS')
plt.xlabel('TOTAL CAMERAS LIVE')
plt.ylabel('TOTAL VIOLATIONS')
plt.scatter(x_violation, y_violation)

# %%
#How does the number of speed cameras correlate with the amount of car violations?

#2022 Prediction of violations (using linear regression)?

x_values= violations_cameras_clean_df["TOTAL CAMERAS LIVE"]
y_values= violations_cameras_clean_df["TOTAL VIOLATIONS"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

plt.title('TOTAL CAMERAS VS VIOLATIONS')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(130,2000),fontsize=12,color="red")
plt.xlabel('TOTAL CAMERAS LIVE')
plt.ylabel('TOTAL VIOLATIONS')
plt.scatter(x_values, y_values) 

print(f"The r-squared is: {rvalue**2}")
print("How does the number of speed cameras correlate with the amount of car violations?")

print("The regression shows a positive correlation.")
print("As the total number of cameras increases, the number of violations increases.")
predicted_violations= slope * 200 + intercept
print(f"For 2022, if the City of Chicago added enough cameras to get to 200 in total, we are predicting that the number of violations would be {predicted_violations}")

plt.show()
# Out:
# The r-squared is: 0.3201195941544464
# How does the number of speed cameras correlate with the amount of car violations?
# The regression shows a positive correlation.
# As the total number of cameras increases, the number of violations increases.
# For 2022, if the City of Chicago added enough cameras to get to 200 in total, we are predicting that the number of violations would be 16329.119684960871

# %%
x_values= violations_cameras_clean_df['TOTAL CAMERAS LIVE']
y_values= violations_cameras_clean_df['VIOLATIONS PER CAMERA']

plt.title('TOTAL CAMERAS VS VIOLATIONS PER CAMERA')

plt.xlabel('TOTAL CAMERAS LIVE')
plt.ylabel('AVG VIOLATIONS PER CAMERA')
plt.scatter(x_values, y_values) 

plt.show()

# %%
x_values= violations_cameras_clean_df['TOTAL CAMERAS LIVE']
y_values= violations_cameras_clean_df['VIOLATIONS PER CAMERA']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

plt.title('TOTAL CAMERAS VS VIOLATIONS PER CAMERA')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(130,20),fontsize=12,color="red")
plt.xlabel('TOTAL CAMERAS LIVE')
plt.ylabel('AVG VIOLATIONS PER CAMERA')
plt.scatter(x_values, y_values) 

print(f"The r-squared is: {rvalue**2}")
print("How does the number of speed cameras correlate with the amount of car violations?")

print("The regression shows a weak correlation.")
print("As the total number of cameras increases, the number of violations increases.")
predicted_violations= slope * 200 + intercept
print(f"Our r-squared value is really low. We do not think our r-squared value is high enough for a prediction.")

plt.show()
# Out:
# The r-squared is: 0.18255848338158343
# How does the number of speed cameras correlate with the amount of car violations?
# The regression shows a weak correlation.
# As the total number of cameras increases, the number of violations increases.
# Our r-squared value is really low. We do not think our r-squared value is high enough for a prediction.

# %%
violations_cameras_clean_df["DATETIME"] = pd.to_datetime(violations_cameras_clean_df["QUARTERLY BINS"])

x_values= violations_cameras_clean_df['DATETIME']
y_values= violations_cameras_clean_df['VIOLATIONS PER CAMERA']

plt.title('TOTAL CAMERAS VS CRASHES')

plt.xlabel('TOTAL CAMERAS LIVE')
plt.ylabel('TOTAL CRASHES')
plt.plot(x_values, y_values) 
plt.xticks(rotation=90)

plt.show()

# %%
#Do speed cameras affect the safety?

print("Do speed cameras affect the safety?")
print("Our highest r-squared value (0.6) was for our 'CAMERAS VS CRASHES' scatter plot.")
print("Based on that scatter plot, the number of car accidents seems to be increasing as more cameras are installed.")
print("The city has not been safer since the cameras have been installed.")
# Out:
# Do speed cameras affect the safety?
# Our highest r-squared value (0.6) was for our 'CAMERAS VS CRASHES' scatter plot.
# Based on that scatter plot, the number of car accidents seems to be increasing as more cameras are installed.
# The city has not been safer since the cameras have been installed.
